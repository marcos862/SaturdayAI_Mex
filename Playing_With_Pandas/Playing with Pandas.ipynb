# %% [markdown]
# ### Importing the required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read the data

# %%
df = pd.read_csv('/home/Marcos862/Downloads/Padron de escuelas beneficiadas Aula 2018.csv')
df.head()
# Out:
#   CLAVE DE CENTRO   NOMBRE DEL CENTRO DE TRABAJO TIPO DE INMUEBLE  \
# 0      01DPR0041W  JOSE GUADALUPE POSADA AGUILAR         PRIMARIA
# 1      01DPR0058W                FEDERICO ENGELS         PRIMARIA
# 2      01DPR0099W               VICENTA TRUJILLO         PRIMARIA
# 3      01DPR0210A              LIC. PRIMO VERDAD         PRIMARIA
# 4      01DPR0222F     JOSE MARIA MORELOS Y PAVON         PRIMARIA
#
#   SUB TIPO DE INMUEBLE  ALUMNOS DE LA ESCUELA           NOMBRE DE CALLE  \
# 0              GENERAL                  163.0           FRANCISCO PONCE
# 1              GENERAL                  199.0                  SAN JUAN
# 2              GENERAL                  266.0           EMILIANO ZAPATA
# 3              GENERAL                  425.0  GUADALUPE NAJERA JIMENEZ
# 4              GENERAL                  230.0                   GERANIO
#
#   NUMERO EXTERIOR             ENTRE CALLE              Y CALLE  \
# 0               0                PONIENTE           POZO NUEVO
# ...

# %%
df.describe()
# Out:
#        ALUMNOS DE LA ESCUELA  CODIGO POSTAL        EDOMUN     EDOMUNLOC  \
# count              65.000000      65.000000     65.000000  6.500000e+01
# mean              325.000000   56553.307692  15860.600000  1.586061e+08
# std               174.715394   17816.854858   6760.966755  6.760961e+07
# min               111.000000   20320.000000   1001.000000  1.001032e+07
# 25%               176.000000   45694.000000  14070.000000  1.407001e+08
# 50%               266.000000   56616.000000  15108.000000  1.510800e+08
# 75%               454.000000   66066.000000  19021.000000  1.902100e+08
# max               756.000000   99110.000000  32042.000000  3.204201e+08
#
#          LONGITUD    LATITUD
# count   65.000000  65.000000
# mean  -100.944498  22.310768
# std      1.716488   2.615010
# min   -105.347261  19.264722
# 25%   -102.270929  19.685000
# 50%   -100.348436  21.805457
# 75%    -99.157127  25.678140
# max    -98.851608  25.844679

# %% [markdown]
# ### Explore the data

# %%
df.columns
# Out:
# Index(['CLAVE DE CENTRO', 'NOMBRE DEL CENTRO DE TRABAJO', 'TIPO DE INMUEBLE',
#        'SUB TIPO DE INMUEBLE', 'ALUMNOS DE LA ESCUELA', 'NOMBRE DE CALLE',
#        'NUMERO EXTERIOR', 'ENTRE CALLE', 'Y CALLE', 'CALLE POSTERIOR',
#        'CODIGO POSTAL', 'ESTADO', 'MUNICIPIO', 'LOCALIDAD', 'EDOMUN',
#        'EDOMUNLOC', 'TIPO DE ZONA RURAL-URBANO', 'LONGITUD', 'LATITUD',
#        'TURNO'],
#       dtype='object')

# %%
df['ESTADO'].drop_duplicates()
# Out:
# 0      AGUASCALIENTES
# 7             JALISCO
# 20             MÉXICO
# 38            NAYARIT
# 39         NUEVO LEÓN
# 60    SAN LUIS POTOSÍ
# 61          ZACATECAS
# 65                NaN
# Name: ESTADO, dtype: object

# %%
df[df['ALUMNOS DE LA ESCUELA']==df['ALUMNOS DE LA ESCUELA'].max()]
# Out:
#    CLAVE DE CENTRO NOMBRE DEL CENTRO DE TRABAJO TIPO DE INMUEBLE  \
# 15      14EPR0649L                   REVOLUCION         PRIMARIA
#
#    SUB TIPO DE INMUEBLE  ALUMNOS DE LA ESCUELA NOMBRE DE CALLE  \
# 15              GENERAL                  756.0      20 DE MAYO
#
#    NUMERO EXTERIOR      ENTRE CALLE     Y CALLE CALLE POSTERIOR  \
# 15            6608  LAZARO CARDENAS  LAS TORRES         NINGUNO
#
#     CODIGO POSTAL   ESTADO MUNICIPIO   LOCALIDAD   EDOMUN    EDOMUNLOC  \
# 15        45690.0  JALISCO  EL SALTO  LAS PINTAS  14070.0  140700013.0
#
#    TIPO DE ZONA RURAL-URBANO    LONGITUD    LATITUD     TURNO
# 15                    URBANA -103.325456  20.573412  MATUTINO

# %%
df[df['ALUMNOS DE LA ESCUELA']==df['ALUMNOS DE LA ESCUELA'].min()]
# Out:
#    CLAVE DE CENTRO NOMBRE DEL CENTRO DE TRABAJO TIPO DE INMUEBLE  \
# 29      15EPR2044I              EMILIANO ZAPATA         PRIMARIA
#
#    SUB TIPO DE INMUEBLE  ALUMNOS DE LA ESCUELA             NOMBRE DE CALLE  \
# 29              GENERAL                  111.0  PRESIDENTE LAZARO CARDENAS
#
#    NUMERO EXTERIOR    ENTRE CALLE Y CALLE CALLE POSTERIOR  CODIGO POSTAL  \
# 29               0  NICOLAS BRAVO       8   BENITO JUAREZ        57920.0
#
#     ESTADO       MUNICIPIO              LOCALIDAD   EDOMUN    EDOMUNLOC  \
# 29  MÉXICO  NEZAHUALCÓYOTL  CIUDAD NEZAHUALCÓYOTL  15058.0  150580001.0
#
#    TIPO DE ZONA RURAL-URBANO   LONGITUD    LATITUD       TURNO
# 29                    URBANA -98.993853  19.377105  VESPERTINO

# %%
df['ALUMNOS DE LA ESCUELA'].mean()
# Out:
# 325.0

# %%
df_rural = df[df['TIPO DE ZONA RURAL-URBANO']!='URBANA']
df_rural.head()
# Out:
#    CLAVE DE CENTRO   NOMBRE DEL CENTRO DE TRABAJO TIPO DE INMUEBLE  \
# 0       01DPR0041W  JOSE GUADALUPE POSADA AGUILAR         PRIMARIA
# 2       01DPR0099W               VICENTA TRUJILLO         PRIMARIA
# 6       01DPR0377H                 FERMIN BECERRA         PRIMARIA
# 10      14DPR2512N                EMILIANO ZAPATA         PRIMARIA
# 19      14EPR1217D         ROBERTO CUELLAR GARCIA         PRIMARIA
#
#    SUB TIPO DE INMUEBLE  ALUMNOS DE LA ESCUELA  \
# 0               GENERAL                  163.0
# 2               GENERAL                  266.0
# 6               GENERAL                  234.0
# 10              GENERAL                  196.0
# 19              GENERAL                  415.0
#
#                     NOMBRE DE CALLE NUMERO EXTERIOR             ENTRE CALLE  \
# 0                   FRANCISCO PONCE               0                PONIENTE
# 2                   EMILIANO ZAPATA               0  INDEPENDENCIA PONIENTE
# ...

# %%
df_urbana = df[df['TIPO DE ZONA RURAL-URBANO']=='URBANA']
df_urbana.head()
# Out:
#   CLAVE DE CENTRO NOMBRE DEL CENTRO DE TRABAJO TIPO DE INMUEBLE  \
# 1      01DPR0058W              FEDERICO ENGELS         PRIMARIA
# 3      01DPR0210A            LIC. PRIMO VERDAD         PRIMARIA
# 4      01DPR0222F   JOSE MARIA MORELOS Y PAVON         PRIMARIA
# 5      01DPR0225C          ADOLFO LOPEZ MATEOS         PRIMARIA
# 7      14DPR0533M               MARIANO AZUELA         PRIMARIA
#
#   SUB TIPO DE INMUEBLE  ALUMNOS DE LA ESCUELA           NOMBRE DE CALLE  \
# 1              GENERAL                  199.0                  SAN JUAN
# 3              GENERAL                  425.0  GUADALUPE NAJERA JIMENEZ
# 4              GENERAL                  230.0                   GERANIO
# 5              GENERAL                  454.0        GUADALUPE VICTORIA
# 7              GENERAL                  475.0                 LUIS MOYA
#
#   NUMERO EXTERIOR     ENTRE CALLE              Y CALLE CALLE POSTERIOR  \
# 1               0  SIN REFERENCIA             SAN JOSE         NINGUNO
# ...

# %%
df_urbana['ALUMNOS DE LA ESCUELA'].mean()
# Out:
# 338.7368421052632

# %%
df_rural['ALUMNOS DE LA ESCUELA'].mean()
# Out:
# 227.125

# %%
tipo_escuela = 'RURAL'
df[df['TIPO DE ZONA RURAL-URBANO'] == tipo_escuela]['ALUMNOS DE LA ESCUELA'].mean()
# Out:
# 227.125

# %%
df['TIPO DE ZONA RURAL-URBANO'].drop_duplicates()
# Out:
# 0      RURAL
# 1     URBANA
# 65       NaN
# Name: TIPO DE ZONA RURAL-URBANO, dtype: object

# %%
tipo_escuela = 'RURAL'
df[df['TIPO DE ZONA RURAL-URBANO'] == NaN]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b9b9467f7986> in <module>
#       1 tipo_escuela = 'RURAL'
# ----> 2 df[df['TIPO DE ZONA RURAL-URBANO'] == NaN]
#
# NameError: name 'NaN' is not defined

# %%
tipo_escuela = np.nan
df[df['TIPO DE ZONA RURAL-URBANO'] == tipo_escuela]
# Out:
# Empty DataFrame
# Columns: [CLAVE DE CENTRO, NOMBRE DEL CENTRO DE TRABAJO, TIPO DE INMUEBLE, SUB TIPO DE INMUEBLE, ALUMNOS DE LA ESCUELA, NOMBRE DE CALLE, NUMERO EXTERIOR, ENTRE CALLE, Y CALLE, CALLE POSTERIOR, CODIGO POSTAL, ESTADO, MUNICIPIO, LOCALIDAD, EDOMUN, EDOMUNLOC, TIPO DE ZONA RURAL-URBANO, LONGITUD, LATITUD, TURNO]
# Index: []

# %%
df[df['TIPO DE ZONA RURAL-URBANO'] == float('nan')]
# Out:
# Empty DataFrame
# Columns: [CLAVE DE CENTRO, NOMBRE DEL CENTRO DE TRABAJO, TIPO DE INMUEBLE, SUB TIPO DE INMUEBLE, ALUMNOS DE LA ESCUELA, NOMBRE DE CALLE, NUMERO EXTERIOR, ENTRE CALLE, Y CALLE, CALLE POSTERIOR, CODIGO POSTAL, ESTADO, MUNICIPIO, LOCALIDAD, EDOMUN, EDOMUNLOC, TIPO DE ZONA RURAL-URBANO, LONGITUD, LATITUD, TURNO]
# Index: []

# %%
df[df['TIPO DE ZONA RURAL-URBANO'].isnull()]
# Out:
#    CLAVE DE CENTRO NOMBRE DEL CENTRO DE TRABAJO TIPO DE INMUEBLE  \
# 65             NaN                          NaN              NaN
# 66             NaN                          NaN              NaN
#
#    SUB TIPO DE INMUEBLE  ALUMNOS DE LA ESCUELA NOMBRE DE CALLE  \
# 65                  NaN                    NaN             NaN
# 66                  NaN                    NaN             NaN
#
#    NUMERO EXTERIOR ENTRE CALLE Y CALLE CALLE POSTERIOR  CODIGO POSTAL ESTADO  \
# 65             NaN         NaN     NaN             NaN            NaN    NaN
# 66             NaN         NaN     NaN             NaN            NaN    NaN
#
#    MUNICIPIO LOCALIDAD  EDOMUN  EDOMUNLOC TIPO DE ZONA RURAL-URBANO  LONGITUD  \
# 65       NaN       NaN     NaN        NaN                       NaN       NaN
# 66       NaN       NaN     NaN        NaN                       NaN       NaN
#
#     LATITUD TURNO
# 65      NaN   NaN
# 66      NaN   NaN

# %%
df[(df['TIPO DE ZONA RURAL-URBANO'] != 'URBANA') & (df['TIPO DE ZONA RURAL-URBANO'] != 'RURAL')].head()
# Out:
#    CLAVE DE CENTRO NOMBRE DEL CENTRO DE TRABAJO TIPO DE INMUEBLE  \
# 65             NaN                          NaN              NaN
# 66             NaN                          NaN              NaN
#
#    SUB TIPO DE INMUEBLE  ALUMNOS DE LA ESCUELA NOMBRE DE CALLE  \
# 65                  NaN                    NaN             NaN
# 66                  NaN                    NaN             NaN
#
#    NUMERO EXTERIOR ENTRE CALLE Y CALLE CALLE POSTERIOR  CODIGO POSTAL ESTADO  \
# 65             NaN         NaN     NaN             NaN            NaN    NaN
# 66             NaN         NaN     NaN             NaN            NaN    NaN
#
#    MUNICIPIO LOCALIDAD  EDOMUN  EDOMUNLOC TIPO DE ZONA RURAL-URBANO  LONGITUD  \
# 65       NaN       NaN     NaN        NaN                       NaN       NaN
# 66       NaN       NaN     NaN        NaN                       NaN       NaN
#
#     LATITUD TURNO
# 65      NaN   NaN
# 66      NaN   NaN

# %%
df.iloc[65,:]
# Out:
# CLAVE DE CENTRO                 NaN
# NOMBRE DEL CENTRO DE TRABAJO    NaN
# TIPO DE INMUEBLE                NaN
# SUB TIPO DE INMUEBLE            NaN
# ALUMNOS DE LA ESCUELA           NaN
# NOMBRE DE CALLE                 NaN
# NUMERO EXTERIOR                 NaN
# ENTRE CALLE                     NaN
# Y CALLE                         NaN
# CALLE POSTERIOR                 NaN
# CODIGO POSTAL                   NaN
# ESTADO                          NaN
# MUNICIPIO                       NaN
# LOCALIDAD                       NaN
# EDOMUN                          NaN
# EDOMUNLOC                       NaN
# TIPO DE ZONA RURAL-URBANO       NaN
# LONGITUD                        NaN
# LATITUD                         NaN
# TURNO                           NaN
# Name: 65, dtype: object

# %%
df['EDOMUN'][31]
# Out:
# 15108.0

# %%
df.loc[31,'EDOMUN']
# Out:
# 15108.0

# %%
df.loc[65,'EDOMUN'] == np.float64('nan')
# Out:
# False

# %%
np.isnan(df.loc[65, 'EDOMUN'])
# Out:
# True

# %%
type(df.loc[65,'TIPO DE ZONA RURAL-URBANO'])
# Out:
# float

# %%
type(np.float64('nan'))
# Out:
# numpy.float64
